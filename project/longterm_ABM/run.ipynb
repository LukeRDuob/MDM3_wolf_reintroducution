# %%
import pandas as pd
from WeeklyModel_ import WeeklySpeciesModel

wolf_numbers = [52, 60, 68, 76, 84]


for wolf_n in wolf_numbers:
    all_results = []

    for run_id in range(25):
        model = WeeklySpeciesModel(max_steps=50000, init_total_wolves=wolf_n)

        while model.running:
            model.step()

        results = model.datacollector.get_model_vars_dataframe().copy()
        results["Week"] = results.index * 0.5
        results["Year"] = results["Week"] / 52
        results["Run"] = run_id

        
        results["Extinction"] = model.stop_reason == "extinction"

        all_results.append(results)

        if model.stop_reason == "extinction":
            print(f"Model {run_id} went extinct at step {model.extinction_step}. Saved with extinction label.")
        else:
            print(f"Model {run_id} finished at max steps and was saved.")

    combined = pd.concat(all_results, ignore_index=True)
    combined.to_csv(f"final_{wolf_n}wolf.csv", index=False)

    print(f"final_{wolf_n}wolf.csv")
# Out:
# Extinction at step 6220
# Model 0 went extinct at step 6220. Saved with extinction label.
# Model 1 finished at max steps and was saved.
# Model 2 finished at max steps and was saved.
# Model 3 finished at max steps and was saved.
# Extinction at step 4450
# Model 4 went extinct at step 4450. Saved with extinction label.
# Extinction at step 7398
# Model 5 went extinct at step 7398. Saved with extinction label.
# Extinction at step 49428
# Model 6 went extinct at step 49428. Saved with extinction label.
# Extinction at step 48247
# Model 7 went extinct at step 48247. Saved with extinction label.
# Model 8 finished at max steps and was saved.
# Extinction at step 7316
# Model 9 went extinct at step 7316. Saved with extinction label.
# Extinction at step 27748
# Model 10 went extinct at step 27748. Saved with extinction label.
# Extinction at step 7003
# Model 11 went extinct at step 7003. Saved with extinction label.
# Model 12 finished at max steps and was saved.
# Extinction at step 8302
# Model 13 went extinct at step 8302. Saved with extinction label.
# Extinction at step 6583
# Model 14 went extinct at step 6583. Saved with extinction label.
# Model 15 finished at max steps and was saved.
# Extinction at step 5801
# Model 16 went extinct at step 5801. Saved with extinction label.
# Model 17 finished at max steps and was saved.
# Model 18 finished at max steps and was saved.
# Model 19 finished at max steps and was saved.
# Extinction at step 10202
# Model 20 went extinct at step 10202. Saved with extinction label.
# Extinction at step 6322
# Model 21 went extinct at step 6322. Saved with extinction label.
# Model 22 finished at max steps and was saved.
# Extinction at step 17334
# Model 23 went extinct at step 17334. Saved with extinction label.
# Model 24 finished at max steps and was saved.
# final_20wolf.csv
# Model 0 finished at max steps and was saved.
# Extinction at step 43953
# Model 1 went extinct at step 43953. Saved with extinction label.
# Extinction at step 5726
# Model 2 went extinct at step 5726. Saved with extinction label.
# Model 3 finished at max steps and was saved.
# Extinction at step 6437
# Model 4 went extinct at step 6437. Saved with extinction label.
# Extinction at step 6915
# Model 5 went extinct at step 6915. Saved with extinction label.
# Extinction at step 5239
# Model 6 went extinct at step 5239. Saved with extinction label.
# Extinction at step 4635
# Model 7 went extinct at step 4635. Saved with extinction label.
# Model 8 finished at max steps and was saved.
# Model 9 finished at max steps and was saved.
# Model 10 finished at max steps and was saved.
# Model 11 finished at max steps and was saved.
# Model 12 finished at max steps and was saved.
# Extinction at step 7457
# Model 13 went extinct at step 7457. Saved with extinction label.
# Model 14 finished at max steps and was saved.
# Model 15 finished at max steps and was saved.
# Extinction at step 5510
# Model 16 went extinct at step 5510. Saved with extinction label.
# Model 17 finished at max steps and was saved.
# Model 18 finished at max steps and was saved.
# Model 19 finished at max steps and was saved.
# Model 20 finished at max steps and was saved.
# Model 21 finished at max steps and was saved.
# Extinction at step 4317
# Model 22 went extinct at step 4317. Saved with extinction label.
# Model 23 finished at max steps and was saved.
# Model 24 finished at max steps and was saved.
# final_28wolf.csv
# Extinction at step 9659
# Model 0 went extinct at step 9659. Saved with extinction label.
# Extinction at step 5373
# Model 1 went extinct at step 5373. Saved with extinction label.
# Extinction at step 39418
# Model 2 went extinct at step 39418. Saved with extinction label.
# Extinction at step 6882
# Model 3 went extinct at step 6882. Saved with extinction label.
# Model 4 finished at max steps and was saved.
# Extinction at step 23254
# Model 5 went extinct at step 23254. Saved with extinction label.
# Model 6 finished at max steps and was saved.
# Extinction at step 43377
# Model 7 went extinct at step 43377. Saved with extinction label.
# Model 8 finished at max steps and was saved.
# Model 9 finished at max steps and was saved.
# Model 10 finished at max steps and was saved.
# Model 11 finished at max steps and was saved.
# Extinction at step 4732
# Model 12 went extinct at step 4732. Saved with extinction label.
# Model 13 finished at max steps and was saved.
# Model 14 finished at max steps and was saved.
# Model 15 finished at max steps and was saved.
# Extinction at step 37971
# Model 16 went extinct at step 37971. Saved with extinction label.
# Extinction at step 6189
# Model 17 went extinct at step 6189. Saved with extinction label.
# Model 18 finished at max steps and was saved.
# Model 19 finished at max steps and was saved.
# Extinction at step 6041
# Model 20 went extinct at step 6041. Saved with extinction label.
# Extinction at step 45224
# Model 21 went extinct at step 45224. Saved with extinction label.
# Extinction at step 5448
# Model 22 went extinct at step 5448. Saved with extinction label.
# Extinction at step 6095
# Model 23 went extinct at step 6095. Saved with extinction label.
# Model 24 finished at max steps and was saved.
# final_36wolf.csv
# Extinction at step 4995
# Model 0 went extinct at step 4995. Saved with extinction label.
# Model 1 finished at max steps and was saved.
# Extinction at step 6961
# Model 2 went extinct at step 6961. Saved with extinction label.
# Model 3 finished at max steps and was saved.
# Extinction at step 5467
# Model 4 went extinct at step 5467. Saved with extinction label.
# Model 5 finished at max steps and was saved.
# Model 6 finished at max steps and was saved.
# Extinction at step 28278
# Model 7 went extinct at step 28278. Saved with extinction label.
# Model 8 finished at max steps and was saved.
# Extinction at step 7764
# Model 9 went extinct at step 7764. Saved with extinction label.
# Model 10 finished at max steps and was saved.
# Model 11 finished at max steps and was saved.
# Extinction at step 8108
# Model 12 went extinct at step 8108. Saved with extinction label.
# Extinction at step 7739
# Model 13 went extinct at step 7739. Saved with extinction label.
# Model 14 finished at max steps and was saved.
# Extinction at step 7309
# Model 15 went extinct at step 7309. Saved with extinction label.
# Extinction at step 8187
# Model 16 went extinct at step 8187. Saved with extinction label.
# Extinction at step 48496
# Model 17 went extinct at step 48496. Saved with extinction label.
# Model 18 finished at max steps and was saved.
# Model 19 finished at max steps and was saved.
# Extinction at step 7357
# Model 20 went extinct at step 7357. Saved with extinction label.
# Extinction at step 6763
# Model 21 went extinct at step 6763. Saved with extinction label.
# Model 22 finished at max steps and was saved.
# Extinction at step 9818
# Model 23 went extinct at step 9818. Saved with extinction label.
# Model 24 finished at max steps and was saved.
# final_44wolf.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 model = WeeklySpeciesModel(max_steps=50000, init_total_wolves=wolf_n)
#      13 while model.running:
# ---> 14     model.step()
#      16 results = model.datacollector.get_model_vars_dataframe().copy()
#      17 results["Week"] = results.index * 0.5
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\model.py:204, in Model._wrapped_step(self)
#     202 def _wrapped_step(self) -> None:
#     203     """Advance time by one unit, processing any scheduled events."""
# --> 204     self._advance_time(self.time + 1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\model.py:229, in Model._advance_time(self, until)
#     227 if event.time <= until:
#     228     self.time = event.time
# --> 229     event.execute()
#     230 else:
#     231     self._event_list.add_event(event)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\time\events.py:130, in Event.execute(self)
#     128 fn = self.fn()
#     129 if fn is not None:
# --> 130     fn(*self.function_args, **self.function_kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\time\events.py:292, in EventGenerator._execute_and_reschedule(self)
#     289     return  # Silent no-op (no error raised)
#     291 # Execute the function
# --> 292 fn()
#     293 self._execution_count += 1
#     295 # Schedule next event if we shouldn't stop
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\model.py:240, in Model._do_step(self)
#     238 self.steps += 1
#     239 _mesa_logger.info(f"Step {self.steps} at time {self.time}")
# --> 240 self._user_step()
#
# File c:\Users\rh23324\MDM3_wolf_reintroducution\project\longterm_ABM\WeeklyModel_.py:194, in WeeklySpeciesModel.step(self)
#     191 self.weekly_wolf_births = 0
#     192 self.weekly_wolf_natural_deaths = 0
# --> 194 self.agents.shuffle_do("step")
#     196 total_deer = sum(d.group_size for d in self.agents_by_type.get(DeerHerd, []))
#     197 total_wolves = sum(w.pack_size for w in self.agents_by_type.get(WolfPack, []))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\agentset.py:771, in _HardKeyAgentSet.shuffle_do(self, method, *args, **kwargs)
#     769     for agent in agents:
#     770         if agent in self._agents:
# --> 771             getattr(agent, method)(*args, **kwargs)
#     772 else:
#     773     for agent in agents:
#
# File c:\Users\rh23324\MDM3_wolf_reintroducution\project\longterm_ABM\DeerHerdAgent_.py:30, in DeerHerd.step(self)
#      29 def step(self):
# ---> 30     self.move()
#      31     #self.model.graze_vegetation(self.pos, self.group_size)
#      33     self.update_group_size()
#
# File c:\Users\rh23324\MDM3_wolf_reintroducution\project\longterm_ABM\DeerHerdAgent_.py:64, in DeerHerd.move(self)
#      62 def move(self):
#      63     wolf_neighbours = [
# ---> 64         n for n in self.model.space.get_neighbors(self.pos, self.sensing_radius, True)
#      65         if n.species == "WolfPack"
#      66     ]
#      68     if len(wolf_neighbours) > 0:
#      69         closest_wolf = self.ret_closest_neighbour(wolf_neighbours)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\mesa\space.py:1420, in ContinuousSpace.get_neighbors(self, pos, radius, include_center)
#    1417 if self._agent_points is None:
#    1418     self._build_agent_cache()
# -> 1420 deltas = np.abs(self._agent_points - np.array(pos))
#    1421 if self.torus:
#    1422     deltas = np.minimum(deltas, self.size - deltas)
#
# KeyboardInterrupt:
